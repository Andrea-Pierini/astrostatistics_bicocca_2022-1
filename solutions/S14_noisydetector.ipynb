# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
import scipy.optimize
from sklearn.decomposition import FastICA, PCA

# %% [markdown]
# Let's start from the back here. These are the signals I injected (you didn't know this of course)

# %%
np.random.seed(0)
n_samples = 2000
time = np.linspace(0, 8, n_samples)

Ttrue = 3.3 # True value of the period!

s1 = np.sin(2*np.pi*time/ Ttrue) + np.random.normal(1,0.3,size=len(time))  # Signal 1 : sinusoidal signal
s2 = np.random.normal(1,1,size=len(time))  # Signal 2 : white noise
s3 = signal.sawtooth(2 * np.pi * time)+np.random.normal(1,0.1,size=len(time))  # Signal 3: saw tooth signal

# %%
fig, axs = plt.subplots(3,figsize=(10,15))

for ax,s in zip(axs,[s1,s2,s3]):
    ax.plot(time,s,c='C0')
        
    ax.set_xlabel('Time')
    #ax.set_ylim(-1.1,1.1)
axs[0].set_title('True signals');

# %% [markdown]
# Then I mixed them together

# %%
S = np.c_[s1, s2, s3]
print(S.shape)

# s1 = [ f_1(t_0), f_1(t_1), f_1(t_2), ...]
# s2 = [ f_2(t_0), f_2(t_1), f_2(t_2), ...]
# s3 = [ f_3(t_0), f_3(t_1), f_3(t_2), ...]
# S = np.c_[s1, s2, s3]
# -> S[0] = [f_1(t_0), f_2(t_0), f_3(t_0)] 
# -> S[i] = [f_1(t_i), f_2(t_i), f_3(t_i)] -> len(S[i]) = 3
# -> S.shape = (2000,3) = (N_samples, N_features)        
# the idea is that we're measuring with 3 telescopes, we have 3 "channels" that are our features;  
# we repeat these measurements over time so we have 2000 samples.
# The purpose of the ICA is to find "sources" as the independent components; hopefully they are less or equal to 3! (they are 2, because we built it in this way)
# this is the reason to treat the data as (2000,3) and thus work on the feature space of 3 "reduced" to 3. 

#S += 0.2 * np.random.normal(size=S.shape)  # Add noise. No, the noise was already added before. 
S /= S.std(axis=0)  # Standardize data
A = np.array([[1, 1, 2], [0.5, 0.5, 0.5], [1, 0.5, 1]])  # Mixing matrix
X = np.dot(S, A.T)  # Generate observations

print(X.shape)
print("Note: scikit learn wants (N_samples, N_features) so here 2000 is samples and 3 is features.")
print("Note the difference with lecture15 where we treated data in the opposite way:")
print("a single wavefunction was 1 sample with N_features = wavelength bins = 1000")
print("and we had N_samples = 4000 different wavefunctions.")
print("there, the purpose was finding some (between 8 and 20) wavefunctions to describe the dataset to find common features!!!")

# np.save('noisydetector.npy',X)
# Out:
# (2000, 3)
# (2000, 3)
# Note: scikit learn wants (N_samples, N_features) so here 2000 is samples and 3 is features.
# Note the difference with lecture15 where we treated data in the opposite way:
# a single wavefunction was 1 sample with N_features = wavelength bins = 1000
# and we had N_samples = 4000 different wavefunctions.
# there, the purpose was finding some (between 8 and 20) wavefunctions to describe the dataset to find common features!!!

# %%
X=np.load('noisydetector.npy')
print(X.shape)

fig, axs = plt.subplots(3,figsize=(10,15))

for ax,s in zip(axs,X.T):
    ax.plot(time,s)
    ax.set_xlabel('Time')
axs[0].set_title('Outputs from three detectors');
# Out:
# (2000, 3)

# %% [markdown]
# Let's look at the PCA components first

# %%
# For comparison, compute PCA
pca = PCA(n_components=3)
H = pca.fit_transform(X)  # Reconstruct signals based on orthogonal components
print(X.shape)
print(H.shape)
print("Note: scikit learn wants (N_samples, N_features) so here 2000 is samples and 3 is features;")

fig, axs = plt.subplots(3,figsize=(10,15))

for ax,s in zip(axs,H.T):
    ax.plot(time,s)
    ax.set_xlabel('Time')
axs[0].set_title('PCA components')    
# not the language I would've used; component seems like the eigenvector of the PCA 
# but it's instead the eigenvalue here (the signal in the eigenvector basis)
# Out:
# (2000, 3)
# (2000, 3)
# Note: scikit learn wants (N_samples, N_features) so here 2000 is samples and 3 is features;
# Text(0.5, 1.0, 'PCA components')

# %% [markdown]
# Mmmhhh... That second component seems to have a pediod close to three but it still contains some of the spike artifacts
#
# Let's try ICA

# %%
np.random.seed(42)

# Compute ICA
ica = FastICA(n_components=3)
S_ = ica.fit_transform(X)  # Reconstruct signals
A_ = ica.mixing_  # Get estimated mixing matrix

fig, axs = plt.subplots(3,figsize=(10,15))

for ax,s in zip(axs,S_.T):
    ax.plot(time,s)
    ax.set_xlabel('Time')
axs[0].set_title('ICA components');

# %% [markdown]
# Given that I'm using three components for a 3-dimensional dataset, the reconstruction should be exact.
# Let's check, just to make sure I don't have a bug somewhere

# %%
np.allclose(X, np.dot(S_, A_.T) + ica.mean_)
# Out:
# True

# %% [markdown]
# The second component is the signal I'm looking for!!!

# %%
mysine = S_[:,1]
plt.plot(time,mysine)

# %% [markdown]
# Today I really feel like a frequentist. I'm going to do a least-square fit:
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.curve_fit.html
#
# If I were Bayesian, I would instead pick a prior and run an MCMC.

# %%
def sinefunc(t,A,T,phi):
    return A*np.sin(2*np.pi*t/T+phi)

paropt,pcov = scipy.optimize.curve_fit(sinefunc,time,mysine, p0=[0.04,4,0])
perr = np.sqrt(np.diag(pcov))

# %%
plt.plot(time, mysine)
bestmodel = sinefunc(time,*paropt)

plt.plot(time, bestmodel)

# %%
print("Recovered time", paropt[1], "+-", perr[1])
print("True value", Ttrue)
# Out:
# Recovered time 3.3180166538020526 +- 0.0082283276998955
# True value 3.3

# %% [markdown]
# Could I use a least-square fit? Only if the errors are Gaussian. This is easy to check:

# %%
diff = mysine-bestmodel

plt.hist(mysine-bestmodel,bins =100, histtype='step',lw=2);

# %% [markdown]
# Which looks preety gaussian to me. We can run a vanilla test for Gaussianity (see [scipy documentation](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.normaltest.html) for details) to obtain a p-value

# %%
scipy.stats.normaltest(diff)
# Out:
# NormaltestResult(statistic=0.956323647989297, pvalue=0.619921870631132)

# %% [markdown]
# I'm overall happy with my result here, altough I have to admit my measurement is two sigma away from the true value.

# %%
(paropt[1] - Ttrue)/perr[1]
# Out:
# 2.1895887547455803

# %% [markdown]
# Could anyone do better?  Did anyone try with MCMC or nested sampling? What did you find?

# %% [markdown]
# If this was a real experiment, the first think would look into would be measurement errors, which is something I am completely neglecting (and they were not provided in the assignment...)
