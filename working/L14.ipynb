# %% [markdown]
# # Lecture 14 - Exercise - The $\gamma$-Ray Burst dataset

# %%
#-------------------------------------------------------------------------
# importing libraries and setting up nice plots
#-------------------------------------------------------------------------

import os
import time
import corner
import requests
import numpy                        as np
import matplotlib                   as mpl
import matplotlib.pyplot            as plt
import matplotlib.patches           as patches
from   matplotlib                   import rc
from   matplotlib.colors            import to_hex
from   mpl_toolkits.axes_grid1      import make_axes_locatable
from   sys                          import stdout
from   scipy                        import stats, integrate
from   astroML                      import stats as astroMLstats
from   astropy.visualization.hist   import hist  as fancyhist
from   astropy.cosmology            import Planck15
from   sklearn.neighbors            import KernelDensity
from   sklearn.manifold             import Isomap
from   sklearn.cluster              import KMeans
from   sklearn.neighbors            import KNeighborsClassifier
from   sklearn.metrics              import confusion_matrix, accuracy_score
from   sklearn.model_selection      import train_test_split, GridSearchCV
from   sklearn.linear_model         import LogisticRegression
from   sklearn.mixture              import GaussianMixture
from   sklearn.decomposition        import PCA

#-------------------------------------------------------------------------

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif" : ["Times New Roman"],
	"font.size"  : 9,
    "figure.dpi" : 300
    })
plt.rc('text.latex', preamble=r'\usepackage{amssymb}')

current_pwd = os.getcwd()
print(current_pwd)

#-------------------------------------------------------------------------
# Out:
# D:\Documents\University\Magistrale\Statistics\GitHub\working

# %%
#-------------------------------------------------------------------------
# Download file
#-------------------------------------------------------------------------

r = requests.get('https://user-web.icecube.wisc.edu/~grbweb_public/Summary_table.txt')
with open("Summary_table.txt", 'wb') as f:
    f.write(r.content)

#-------------------------------------------------------------------------
# Read content

data = np.loadtxt("Summary_table.txt", dtype='str',unpack='True')

#-------------------------------------------------------------------------
# Read headers
with open("Summary_table.txt",'r') as f:
    names = np.array([n.strip().replace(" ","_") for n in f.readlines()[1].replace("#","").replace("\n","").lstrip().split('    ') if n.strip()!=''])

for name in names:
    print(name)

print()
print(data.shape)
# Out:
# GRB_name
# GRB_name_Fermi
# T0
# ra
# decl
# pos_error
# T90
# T90_error
# T90_start
# fluence
# fluence_error
# redshift
# 'T100'
# GBM_located
# mjd_(T0)
#
# (15, 8722)

# %% [markdown]
# Reading the documentation, the first two columns data[0], data[1] are just names according to two different convention (no physics involved).
#
# (RA = right ascension, DECL = declination, pos_error) indicate the two angular positions of the burst and the error on this localisation.
#
# T0 = Earliest UTC time at which activity was reported from the GRB. This time corresponds to the earliest trigger time of the satellites or the start of the T90 interval if it preceeds those trigger time. (probably, not that relevant physically)
#
# T90_start = UTC time that marks the start of the T90 interval. (probably, also not that relevant physically)
#
# (T90, T90_error) = Duration of the time interval during which 90% of the GRB photon counts are observed, starting at 5% and ending at 95%; and the estimated 1σ error on the duration of the T90 interval.
#
# T100 = Total time during which the GRB was observed. In practice, this variable is obtained by subtracting the earliest trigger time from the latest end of the T90 intervals. (probably, less relevant than T90 due to more error / long tails)
#
# (fluence, fluence_error) = The time integrated total energy per unit surface. Please note that the observed value strongly depends on the energy band and thus the detector that observed the burst. $1\sigma$ error on it.
#
# redshift = redshift of GRB (so, info on distance)

# %%
#-------------------------------------------------------------------------
# Collect the variables we're primarily interested in
#-------------------------------------------------------------------------

# T90 and its error
T  = np.array(data[6],dtype=float)
eT = np.array(data[7],dtype=float)

# fluence and its error
F  = np.array(data[9],dtype=float)
eF = np.array(data[10],dtype=float)

# redshift
z  = np.array(data[11],dtype=float)

#-------------------------------------------------------------------------
# Collect the variables we're secondarily interested in (location)

ra = np.array(data[3],dtype=float)
de = np.array(data[4],dtype=float)
ep = np.array(data[5],dtype=float)

del data

#-------------------------------------------------------------------------------------------
# trim unphysical data such as T90<0, F<0, z<0

F  = F[T>0]
eF = eF[T>0]
z  = z[T>0]
ra = ra[T>0]
de = de[T>0]
ep = ep[T>0]
eT = eT[T>0]
T  = T[T>0]
N = len(T)

print(T.shape)

#-------------------------------------------------------------------------
# Out:
# (7592,)

# %%
#-------------------------------------------------------------------------------------------
# just defining a quicker way to call the Kernel Density Estimator and the Gaussian Mixture
#-------------------------------------------------------------------------------------------

#-------------------------------------------------------------------------------------------
# Epanechnikov KDE (linear in data)

def KDE_GSCV(data, kernel="epanechnikov", size=1000, density=True, GSCV=False, bandwidth=1):

    data_skl = data[:, np.newaxis]
    
    xgrid = np.linspace( data.min(), data.max(), size)
    
    if GSCV == False:
        kde_skl = KernelDensity(bandwidth=bandwidth, kernel=kernel)

    else:
        K = 5 
        bandwidth_range = np.linspace(0.01,2.00, 50)
        grid = GridSearchCV(KernelDensity(), {'bandwidth': bandwidth_range}, cv=K) 
        grid.fit(data_skl) 
        bandwidth_opt = grid.best_params_['bandwidth']
        kde_skl = KernelDensity(bandwidth=bandwidth_opt, kernel=kernel)

    kde_skl.fit(data_skl)
    
    log_pdf = kde_skl.score_samples(xgrid[:, np.newaxis]) 
    pdf_x = np.exp(log_pdf)
    
    if density==False:
        data_bins = np.linspace( data.min(), data.max(), 30)
        counts , _ = np.histogram(data, bins=data_bins, density=False)
        norm = counts.max() / pdf_x.max()
        pdf_x = pdf_x * norm
    
    return pdf_x , xgrid

#-------------------------------------------------------------------------------------------
# Epanechnikov KDE (log10 in data)

def KDE_GSCV_log(data, kernel="epanechnikov", size=1000, density=True, GSCV=False, bandwidth=1):

    logdata_skl = np.log10(data[:, np.newaxis])

    ygrid = np.linspace( np.log10(data.min()) , np.log10(data.max()), size)
    xgrid = 10**ygrid
    dx_dy = np.log(10) * 10**ygrid                                # dy_dx = 1/(xgrid * np.log(10))

    if GSCV == False:
        kde_skl = KernelDensity(bandwidth=bandwidth, kernel=kernel)

    else:
        K = 5 
        bandwidth_range = np.linspace(0.01,2.00, 50)
        grid = GridSearchCV(KernelDensity(), {'bandwidth': bandwidth_range}, cv=K) 
        grid.fit(logdata_skl) 
        bandwidth_opt = grid.best_params_['bandwidth']
        kde_skl = KernelDensity(bandwidth=bandwidth_opt, kernel=kernel)

    kde_skl.fit(logdata_skl)

    log_pdf_y = kde_skl.score_samples(ygrid[:, np.newaxis])
    pdf_y = np.exp(log_pdf_y)

    if density==True:
        pdf_x = pdf_y / dx_dy                                         # * dy_dx

    elif density==False:
        data_bins = np.logspace(np.log10(data.min()), np.log10(data.max()), 30)
        counts , _ = np.histogram(data, bins=data_bins, density=False)
        norm = counts.max() / pdf_y.max()
        pdf_x = pdf_y * norm

    return pdf_x , xgrid

#-------------------------------------------------------------------------------------------
# Gaussian Mixture (log10 in data)

def TwoGaussians_log(data, n_components=2, n_init=25, size=1000, density=True):

    logdata_skl = np.log10(data[:, np.newaxis])

    ygrid = np.linspace( np.log10(data.min()) , np.log10(data.max()), size)
    xgrid = 10**ygrid
    dx_dy = np.log(10) * 10**ygrid                                # dy_dx = 1/(xgrid * np.log(10))

    TwoGaussians_skl = GaussianMixture(n_components=n_components, n_init=25)
    TwoGaussians_skl.fit(logdata_skl)

    log_pdf_y = TwoGaussians_skl.score_samples(ygrid[:, np.newaxis])
    pdf_y = np.exp(log_pdf_y)

    responsibilities = TwoGaussians_skl.predict_proba(ygrid[:, np.newaxis])
    pdf_y_c1 = responsibilities[:,0] * pdf_y
    pdf_y_c2 = responsibilities[:,1] * pdf_y

    data_means = 10**np.squeeze(TwoGaussians_skl.means_)
    data_responsibility = TwoGaussians_skl.predict_proba(logdata_skl)
    data_aic = TwoGaussians_skl.aic(logdata_skl)
    data_bic = TwoGaussians_skl.bic(logdata_skl)

    if data_means[0] > data_means[1]:
        data_means = data_means[::-1]
        data_responsibility = data_responsibility[:,::-1]
        
    data_labels = np.array(data_responsibility[:,0] < data_responsibility[:,1], dtype='int')

    if density==True:
        pdf_x = pdf_y / dx_dy                                         # * dy_dx
        pdf_x_c1 = pdf_y_c1 / dx_dy
        pdf_x_c2 = pdf_y_c2 / dx_dy

    elif density==False:
        data_bins = np.logspace(np.log10(data.min()), np.log10(data.max()), 30)
        counts , _ = np.histogram(data, bins=data_bins, density=False)
        norm = counts.max() / pdf_y.max()
        pdf_x = pdf_y * norm
        pdf_x_c1 = pdf_y_c1 * norm
        pdf_x_c2 = pdf_y_c2 * norm

    return pdf_x , xgrid , data_means, data_labels, data_aic, data_bic, pdf_x_c1, pdf_x_c2

#-------------------------------------------------------------------------------------------
# K-means classifier (log10 in data)

def Kmeans_log(data, nclusters=2):

    logdata_skl = np.log10(data[:, np.newaxis])

    classifier = KMeans(n_clusters=2)
    classifier.fit(logdata_skl)

    data_centres = 10**np.squeeze(classifier.cluster_centers_)
    data_labels  = classifier.predict(logdata_skl) 

    if data_centres[0] > data_centres[1]:   # check sorting
        data_centres = data_centres[::-1]   # if not, reverse
        data_labels = np.array(~np.array(data_labels,dtype='bool'), dtype='int') # Swap 0 <--> 1 

    return data_centres, data_labels

# %%
#-------------------------------------------------------------------------------------------
# Quick look at the data: some histograms
#-------------------------------------------------------------------------------------------

fig , ax = plt.subplots(1,3,figsize=(12,5))

normalize = False

#-------------------------------------------------------------------------------------------

ax[0].set_xlabel(r"duration $T_{90} \; [\textup{s}]$")
ax[0].set_xlim(2e-3,1e3)
ax[0].set_xscale('log')

_ = fancyhist(T, ax=ax[0], bins=np.logspace(-3,5,40), histtype="step", density=normalize, alpha=0.75, color='lightcoral')

PDF_T_KDE_nn, T_KDE_nn = KDE_GSCV_log(T, kernel="epanechnikov", density=normalize, GSCV=False, bandwidth=0.45)
ax[0].plot(T_KDE_nn, PDF_T_KDE_nn, ls='-', lw=1, color='lightskyblue', label='Epanechnikov KDE')

#-------------------------------------------------------------------------------------------

ax[1].set_xlabel(r"fluence $F \; [\textup{erg}/\textup{cm}^2]$")
ax[1].set_xscale('log')
ax[1].set_yscale('log')
ax[1].set_xlim(1e-9,1e-1)

_ = fancyhist(F[F>0], ax=ax[1], bins=np.logspace(-9,-1,16), histtype="step", density=normalize, alpha=0.75, color='lightcoral')

PDF_F_KDE_nn, F_KDE_nn = KDE_GSCV_log(F[F>0], kernel="epanechnikov", density=normalize, GSCV=False, bandwidth=1.)
ax[1].plot(F_KDE_nn, PDF_F_KDE_nn, ls='-', lw=1, color='lightskyblue', label='Epanechnikov KDE')

#-------------------------------------------------------------------------------------------

ax[2].set_xlabel(r"redshift $z$")
ax[2].set_xlim(0,12)
_ = fancyhist(z[z>0], ax=ax[2], bins='freedman', histtype="step", density=normalize, alpha=0.75, color='lightcoral')

PDF_z_KDE_nn, z_KDE_nn = KDE_GSCV(z[z>0], kernel="epanechnikov", density=normalize, GSCV=False, bandwidth=1.)
ax[2].plot(z_KDE_nn, PDF_z_KDE_nn, ls='-', lw=1, color='lightskyblue', label='Epanechnikov KDE')

# --------------------------------------------------------------------------------------
# Utility: legend, saving the figure...

# _ = ax[0].legend(loc=1,frameon=True, framealpha=1, fancybox=False, edgecolor='black')

# do we want to save the figure?
if False:
    if current_pwd[-6:] == 'GitHub':
        fig.savefig('./working/L14_images/L14_GRB_first_look_histograms.pdf', bbox_inches='tight')
    elif current_pwd[-14:] == 'GitHub\working':
        fig.savefig('./L14_images/L14_GRB_first_look_histograms.pdf', bbox_inches='tight')

# %%
#-------------------------------------------------------------------------------------------
# Quick look at the data: some histograms
#-------------------------------------------------------------------------------------------

fig , ax = plt.subplots(1,3,figsize=(12,5))

normalize = True

#-------------------------------------------------------------------------------------------

ax[0].set_xlabel(r"duration $T_{90} \; [\textup{s}]$")
ax[0].set_xlim(2e-3,1e3)
ax[0].set_xscale('log')

_ = fancyhist(T, ax=ax[0], bins=np.logspace(-3,5,40), histtype="step", density=normalize, alpha=0.75, color='lightcoral')

PDF_T_KDE, T_KDE = KDE_GSCV_log(T, kernel="epanechnikov", density=normalize, GSCV=False, bandwidth=0.45)
ax[0].plot(T_KDE, PDF_T_KDE, ls='-', lw=1, color='lightskyblue', label='Epanechnikov KDE')

#-------------------------------------------------------------------------------------------

ax[1].set_xlabel(r"fluence $F \; [\textup{erg}/\textup{cm}^2]$")
ax[1].set_xscale('log')
ax[1].set_yscale('log')
ax[1].set_xlim(1e-9,1e-1)

_ = fancyhist(F[F>0], ax=ax[1], bins=np.logspace(-9,-1,16), histtype="step", density=normalize, alpha=0.75, color='lightcoral')

PDF_F_KDE, F_KDE = KDE_GSCV_log(F[F>0], kernel="epanechnikov", density=normalize, GSCV=False, bandwidth=1.)
ax[1].plot(F_KDE, PDF_F_KDE, ls='-', lw=1, color='lightskyblue', label='Epanechnikov KDE')

#-------------------------------------------------------------------------------------------

ax[2].set_xlabel(r"redshift $z$")
ax[2].set_xlim(0,12)
_ = fancyhist(z[z>0], ax=ax[2], bins='freedman', histtype="step", density=normalize, alpha=0.75, color='lightcoral')

PDF_z_KDE, z_KDE = KDE_GSCV(z[z>0], kernel="epanechnikov", density=normalize, GSCV=False, bandwidth=1.)
ax[2].plot(z_KDE, PDF_z_KDE, ls='-', lw=1, color='lightskyblue', label='Epanechnikov KDE')

# --------------------------------------------------------------------------------------
# Utility: legend, saving the figure...

# _ = ax[0].legend(loc=1,frameon=True, framealpha=1, fancybox=False, edgecolor='black')

# do we want to save the figure?
if False:
    if current_pwd[-6:] == 'GitHub':
        fig.savefig('./working/L14_images/L14_GRB_first_look_histograms_normalized.pdf', bbox_inches='tight')
    elif current_pwd[-14:] == 'GitHub\working':
        fig.savefig('./L14_images/L14_GRB_first_look_histograms_normalized.pdf', bbox_inches='tight')

# %% [markdown]
# From the T90 histogram and kernel density estimator, it looks like there are two populations of $\gamma$-ray bursts: one with shorter durations peaking around 0.1s, and one with longer durations peaking around 30s.
#
# Let us therefore try to use a classifier to find two clusters in  the duration space.
#
# Let us also try to fit the T90 histogram with a gaussian mixture with 2 components.

# %%
logT_sklearn = np.log10(T)[:, np.newaxis]

#-------------------------------------------------------------------------------------------
# K-means clustering with 2 clusters

centres_kmeans, labels_kmeans = Kmeans_log(T, nclusters=2)
print('\nk-means centres: {:.2f} , {:.2f}'.format(centres_kmeans[0],centres_kmeans[1]))

#-------------------------------------------------------------------------------------------
# gaussian mixture with 2 componensts

PDF_T_2G, T_2G, centres_2G, labels_2G, aic_2G, bic_2G, PDF_T_2G_c1, PDF_T_2G_c2 = TwoGaussians_log(T, n_components=2, n_init=25)
print('\nGaussian centres: {:.2f} , {:.2f}'.format(centres_2G[0],centres_2G[1]))

# confirm that there are only 2 modes by computing the information criteria also for 3 and 4 components; 
# verify that it is minimized by 2 components
PDF_T_3G, T_3G, _, _, aic_3G, bic_3G, _, _ = TwoGaussians_log(T, n_components=3, n_init=25)
PDF_T_4G, T_4G, _, _, aic_4G, bic_4G, _, _ = TwoGaussians_log(T, n_components=4, n_init=25)
print('aic: 2 Gaussians = {:.5e} ; 3 Gaussians = {:.5e} ; 4 Gaussians = {:.5e}'.format(aic_2G, aic_3G, aic_4G))
print('bic: 2 Gaussians = {:.5e} ; 3 Gaussians = {:.5e} ; 4 Gaussians = {:.5e}'.format(bic_2G, bic_3G, bic_4G))

#-------------------------------------------------------------------------------------------
# compare the classifications based on K-means and Gaussian Mixture

labels_difference = confusion_matrix(labels_2G,labels_kmeans)
print()
print(labels_difference)

#-------------------------------------------------------------------------------------------

fig , ax = plt.subplots(1,2,figsize=(8,4))

for i in [0,1]:
    ax[i].set_xlabel(r"duration $T_{90} \; [\textup{s}]$")
    ax[i].set_xlim(2e-3,1e3)
    ax[i].set_xscale('log')

#-------------------------------------------------------------------------------------------
# histogram for T90 (normalized)

_ = fancyhist(T, ax=ax[0], bins=np.logspace(-3,5,40), histtype="step", density=True, alpha=0.75, color='lightcoral')

ax[0].plot(T_KDE, PDF_T_KDE, ls='-', lw=1, color='lightskyblue', label='Epanechnikov KDE')

ax[0].plot(T_2G, PDF_T_2G, ls='-', lw=1, color='khaki', label='2 Gaussians Mixture')
ax[0].plot(T_2G, PDF_T_2G_c1, ls=':', lw=1, color='khaki')
ax[0].plot(T_2G, PDF_T_2G_c2, ls=':', lw=1, color='khaki')

# ax[0].plot(T_2G, PDF_T_2G, ls=':', lw=1, color='black', label='3 Gaussians Mixture')
# ax[0].plot(T_2G, PDF_T_2G, ls='-.', lw=1, color='black', label='4 Gaussians Mixture')

#-------------------------------------------------------------------------------------------
# histogram for T90 (not normalized)

_ = fancyhist(T, ax=ax[1], bins=np.logspace(-3,5,40), histtype="step", density=False, alpha=0.75, color='lightcoral')

ax[1].plot(T_KDE_nn, PDF_T_KDE_nn, ls='-', lw=1, color='lightskyblue', label='Epanechnikov KDE'+ '\n(arbitrarily renorm.)')

PDF_T_2G_nn, T_2G_nn , _ , _ , _ , _ , PDF_T_2G_c1_nn, PDF_T_2G_c2_nn = TwoGaussians_log(T, n_components=2, n_init=25, density=False)
ax[1].plot(T_2G_nn, PDF_T_2G_nn, ls='-', lw=1, color='khaki', label='2 Gaussians Mixture'+ '\n(arbitrarily renorm.)')
ax[1].plot(T_2G_nn, PDF_T_2G_c1_nn, ls=':', lw=1, color='khaki')
ax[1].plot(T_2G_nn, PDF_T_2G_c2_nn, ls=':', lw=1, color='khaki')

ax[1].vlines(centres_2G, ymin=0, ymax=1e3, colors='black', ls='--', lw=0.85, label='2 Gaussian centres' + '\nat {:.2f} s, {:.2f} s'.format(centres_kmeans[0],centres_kmeans[1]))    # ymax=0.25 if normalized, otherwise 1e3
ax[1].vlines(centres_kmeans, ymin=0, ymax=1e3, colors='black', ls=':', lw=0.85, label='2 K-means centres' + '\nat {:.2f} s, {:.2f} s'.format(centres_2G[0],centres_2G[1]))   # ymax=0.25 if normalized, otherwise 1e3

#-------------------------------------------------------------------------------------------

for i, loc in zip([0,1],[1,2]):
    _ = ax[i].legend(loc=loc, frameon=True, framealpha=1, fancybox=False, edgecolor='black')

# do we want to save the figure?
if False:
    if current_pwd[-6:] == 'GitHub':
        fig.savefig('./working/L14_images/L14_GRB_T_histogram__KDE_and_2G.pdf', bbox_inches='tight')
    elif current_pwd[-14:] == 'GitHub\working':
        fig.savefig('./L14_images/L14_GRB_T_histogram__KDE_and_2G.pdf', bbox_inches='tight')
# Out:
# k-means centres: 0.91 , 33.20
#
# Gaussian centres: 0.97 , 30.71
# aic: 2 Gaussians = 1.69594e+04 ; 3 Gaussians = 1.69931e+04 ; 4 Gaussians = 1.70150e+04
# bic: 2 Gaussians = 1.69940e+04 ; 3 Gaussians = 1.70486e+04 ; 4 Gaussians = 1.70912e+04
#
# [[1681    0]
#  [ 281 5630]]

# %%
#-------------------------------------------------------------------------------------------
# clustered data in T: scatter-plots (T-F), (z-T), (z-F)
#-------------------------------------------------------------------------------------------

fig , ax = plt.subplots(2,2,figsize=(8,7))
ax = ax.reshape(4)

#-------------------------------------------------------------------------
# define a discrete colormap for the two clusters

cmap   = mpl.cm.bwr   # diverging cmaps: PiYG, seismic; uniform looking cmaps: magma, plasma
cmapl  = [cmap(i) for i in range(cmap.N)]
cmap   = mpl.colors.LinearSegmentedColormap.from_list('Custom cmap', cmapl, cmap.N)
bounds = np.linspace(-0.5, 1.5, 3)
ticks  = np.linspace(0., 1., 2)
tlabs  = ['SGRB','LGRB']
norm   = mpl.colors.BoundaryNorm(bounds, cmap.N)

#-------------------------------------------------------------------------

ax[0].set_title(r"Clustereing: k-means")
ax[0].set_xlabel(r"duration $T_{90} \; [\textup{s}]$")
ax[0].set_xlim(1e-2,1e4)
ax[0].set_xscale('log')
ax[0].set_ylabel(r"fluence $F \; [\textup{erg}/\textup{cm}^2]$")
ax[0].set_ylim(1e-9,1e-1)
ax[0].set_yscale('log')

ax[0].scatter(T, F, c=labels_kmeans, s=0.1, cmap=cmap, norm=norm)

#-------------------------------------------------------------------------

ax[1].set_title(r"Clustering: gaussian mixture responsibility")
ax[1].set_xlabel(r"duration $T_{90} \; [\textup{s}]$")
ax[1].set_xlim(1e-2,1e4)
ax[1].set_xscale('log')
ax[1].set_ylabel(r"fluence $F \; [\textup{erg}/\textup{cm}^2]$")
ax[1].set_ylim(1e-9,1e-1)
ax[1].set_yscale('log')

ax[1].scatter(T, F, c=labels_2G, s=0.1, cmap=cmap, norm=norm)

#-------------------------------------------------------------------------------------------

ax[2].set_xlabel(r"redshift $z$")
ax[2].set_ylabel(r"duration $T_{90} \; [\textup{s}]$")
ax[2].set_ylim(1e-2,1e4)
ax[2].set_yscale('log')

ax[2].scatter(z[z>0], T[z>0], c=labels_2G[z>0], s=0.1, cmap=cmap, norm=norm)

#-------------------------------------------------------------------------------------------

ax[3].set_xlabel(r"redshift $z$")
ax[3].set_ylabel(r"fluence $F \; [\textup{erg}/\textup{cm}^2]$")
ax[3].set_ylim(1e-9,1e-1)
ax[3].set_yscale('log')

ax[3].scatter(z[z>0], F[z>0], c=labels_2G[z>0], s=0.1, cmap=cmap, norm=norm)

# --------------------------------------------------------------------------------------
# plot colorbars with clustering labels

for i in range(4):
    divid  = make_axes_locatable(ax[i])
    cmapax = divid.append_axes('right', size='5%', pad=0.10)
    cbar   = mpl.colorbar.ColorbarBase(cmapax, cmap=cmap, norm=norm, spacing='proportional', ticks=ticks, boundaries=bounds, format='%1i')
    cbar.ax.set_yticklabels(tlabs)


# --------------------------------------------------------------------------------------
# Utility: legend, saving the figure...

if False:
    for i in range(3):
        _ = ax[i].legend(loc=1,frameon=True, framealpha=1, fancybox=False, edgecolor='black')

fig.tight_layout()

# do we want to save the figure?
if False:
    if current_pwd[-6:] == 'GitHub':
        fig.savefig('./working/L14_images/L14_GRB_clustered.pdf', bbox_inches='tight')
    elif current_pwd[-14:] == 'GitHub\working':
        fig.savefig('./L14_images/L14_GRB_clustered.pdf', bbox_inches='tight')

# %% [markdown]
# The two clustering methods provide extremely similar results. From the confusion matrix and the plot, it seems that all sources classified as SGRB from GaussianMixture are also classified as SGRB by K-means; only around 5% of sources classified as LGRB from GaussianMixture are classified instead as SGRB by K-means.
#
# It seems that SGRB have (slightly) lower redshift and (veeeery slightly) lower fluence, though the sources with measured redshift make for a much smaller dataset.
#
# Let us investigate a bit more the "edge" between the two clusters by evaluating how many SGRB or LGRB lie below an increasing value of T90:

# %%
fig , ax = plt.subplots(figsize=(5.5,5))

ax.set_xlabel(r"duration threshold $\tilde{T}_{90} \; [\textup{s}]$")
ax.set_xlim(T.min(),T.max())
ax.set_xscale('log')
ax.set_ylim(-200,6200)

SGRB_below_threshold_2G = np.array([np.sum( labels_2G[T<t]==0) for t in T_2G])
LGRB_below_threshold_2G = np.array([np.sum( labels_2G[T<t]==1) for t in T_2G])
SGRB_below_threshold_kmeans = np.array([np.sum( labels_kmeans[T<t]==0) for t in T_2G])
LGRB_below_threshold_kmeans = np.array([np.sum( labels_kmeans[T<t]==1) for t in T_2G])

ax.plot(T_2G, SGRB_below_threshold_2G, color='lightskyblue', ls='--', lw=0.85, label=r'$\#$' + ' of SGRB below threshold' + '\n' + 'clustered with GaussianMixture')
ax.plot(T_2G, SGRB_below_threshold_kmeans, color='lightskyblue', ls=':', lw=0.85, label=r'$\#$' + ' of SGRB below threshold' + '\n' + 'clustered with K-means')
ax.plot(T_2G, LGRB_below_threshold_2G, color='lightcoral', ls='--', lw=0.85, label=r'$\#$' + ' of LGRB below threshold' + '\n' + 'clustered with GaussianMixture')
ax.plot(T_2G, LGRB_below_threshold_kmeans, color='lightcoral', ls=':', lw=0.85, label=r'$\#$' + ' of LGRB below threshold' + '\n' + 'clustered with K-means')

plt.axvspan(2,3,alpha=0.25,color='khaki',label='Typical separation in literature ')


i_2G = np.where( LGRB_below_threshold_2G > 0 )
T_edge_2G = T_2G[i_2G[0][0]]
print(T_edge_2G)
ax.vlines( T_edge_2G, ymin=-200, ymax=6200, color='black', ls='--', lw=0.85, label=r'$\tilde{T}_{90} = \;$' + '{:.2f} = rough threshold\nestimate (GaussianMixture)'.format(T_edge_2G))


i_kmeans = np.where( LGRB_below_threshold_kmeans > 0 )
T_edge_kmeans = T_2G[i_kmeans[0][0]]
print(T_edge_kmeans)
ax.vlines( T_edge_kmeans, ymin=-200, ymax=6200, color='black', ls=':', lw=0.85, label=r'$\tilde{T}_{90} = \;$' + '{:.2f} = rough threshold\nestimate (K-means)'.format(T_edge_kmeans))

_ = ax.legend(loc=2,frameon=True, framealpha=1, fancybox=False, edgecolor='black')

# do we want to save the figure?
if False:
    if current_pwd[-6:] == 'GitHub':
        fig.savefig('./working/L14_images/L14_GRB_clustered_edge.pdf', bbox_inches='tight')
    elif current_pwd[-14:] == 'GitHub\working':
        fig.savefig('./L14_images/L14_GRB_clustered_edge.pdf', bbox_inches='tight')
# Out:
# 3.9234552394633093
# 5.566166721555946

# %%
def distrib_theory(var_z):
    return 4*np.pi * Planck15.differential_comoving_volume(var_z).value

def distrib_normal(var_z, var_min=0, var_max=z.max()):
    return integrate.quad(distrib_theory, var_min, var_max)[0]

def distrib_theory_normal(var_z, var_min=0, var_max=z.max()):
    return distrib_theory(var_z) / distrib_normal(var_z, var_min=var_min, var_max=var_max)

zz = np.linspace(0,z.max(),1000)
yy = 2.6 * distrib_theory_normal(zz)

fig , ax = plt.subplots(figsize=(4, 4))

ax.set_xlim(0,12)
ax.set_xlabel('redshift $z$')
ax.set_ylabel(r'$p(z) \, \textup{d}z$')

_ = fancyhist(z[z>0], bins='freedman', ax=ax, histtype='step', density=True, color='lightcoral')


ax.plot(zz, yy, color='black', label='uniformly distributed\n' + r'in Flat $\Lambda$CDM' + '\n' + '(manually normal.)') ###   Arbitrary normalization, just matching by eye

ax.legend(frameon=True, framealpha=1, fancybox=False, edgecolor='black', loc=1)

# %%
_ = '''
z  = z[F>0]
ra = ra[F>0]
de = de[F>0]
ep = ep[F>0]
eT = eT[F>0]
T  = T[F>0]
eF = eF[F>0]
F  = F[F>0]

ra = ra[z>0]
de = de[z>0]
ep = ep[z>0]
eT = eT[z>0]
T  = T [z>0]
eF = eF[z>0]
F  = F [z>0]
z  = z [z>0]

'''

# %%
#-------------------------------------------------------------------------
# reduction of the dimensionality of the dataset: 
# try Isomap to find a D=2 surface embedded in D=3
#-------------------------------------------------------------------------


TZ = np.array([T[z>0],z[z>0]]).T
print(TZ.shape)

embedding = Isomap(n_components=1)
TZ_isomap = embedding.fit_transform(TZ)
print(TZ_isomap.shape)

#-------------------------------------------------------------------------
# reduction of the dimensionality of the dataset: 
# try PCA to find Principal Components 
#-------------------------------------------------------------------------

pca    = PCA(n_components=1)
TZ_pca = pca.fit_transform(TZ)
print(TZ_pca.shape)

print(pca.components_)

#-------------------------------------------------------------------------
# Out:
# (596, 2)
# (596, 1)
# (596, 1)
# [[9.99999996e-01 8.67455144e-05]]
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\manifold\_isomap.py:384: UserWarning: The number of connected components of the neighbors graph is 3 > 1. Completing the graph to fit Isomap might be slow. Increase the number of neighbors to avoid this issue.
#   self._fit_transform(X)
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\scipy\sparse\_index.py:82: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\scipy\sparse\_index.py:82: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\scipy\sparse\_index.py:82: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])

# %%
#-------------------------------------------------------------------------
# Plot the D=2 reduction of the D=3 dataset
# NOTE: we haven't clustered the data yet
#-------------------------------------------------------------------------

fig , ax = plt.subplots(1,2,figsize=(8,4))

#-------------------------------------------------------------------------

ax[0].grid(ls=':')
lims = (TZ_isomap.min(),TZ_isomap.max()) 
print(lims)
loglims = np.log10(lims)
print(loglims)
ax[0].set_xlim(lims)
# ax[0].set_xscale('log')
# ax[0].set_ylim(0,10)
ax[0].set_title('2D Reduction of the dataset:\nIsomap $D=2$ embedding in $D=3$')
# leplot_isomap = ax[0].scatter( TZ_isomap[:,0], TZ_isomap[:,1], c='lightskyblue', s=1)
_ = fancyhist(TZ_isomap, ax=ax[0], bins=100, histtype="step", density=False, alpha=0.75, color='lightcoral')


#-------------------------------------------------------------------------

ax[1].grid(ls=':')
lims = (TZ_pca.min(),TZ_pca.max()) 
print(lims)
loglims = np.log10(lims)
print(loglims)
ax[1].set_xlim(lims)
# ax[1].set_xscale('log')
ax[1].set_title('2D Reduction of the dataset:\nPrincipal Component Analysis $C=2$')
# leplot_pca = ax[1].scatter( TZ_pca[:,0], TZ_pca[:,0], c='lightskyblue', s=1)
_ = fancyhist(TZ_pca, ax=ax[1], bins=100, histtype="step", density=False, alpha=0.75, color='lightcoral')



print("PCA projection of the 2 components:")
for component in pca.components_:
    print(" + ".join("%.10e x %s" % (value, name) for value, name in zip(component, ['T90', 'z'])))

#-------------------------------------------------------------------------
# savefig and additional notes

fig.tight_layout()

# do we want to save the figure?
if False:
    if current_pwd[-6:] == 'GitHub':
        fig.savefig('./working/L14_images/L14_GRB_first_look_reduced_dim.pdf', bbox_inches='tight')
    elif current_pwd[-14:] == 'GitHub\working':
        fig.savefig('./L14_images/L14_GRB_first_look_reduced_dim.pdf', bbox_inches='tight')

#-------------------------------------------------------------------------
# Out:
# (-79.25171693084503, 2025.3474812069499)
# [       nan 3.30649954]
# (-78.31222247424057, 2021.651739012379)
# [       nan 3.30570634]
# PCA projection of the 2 components:
# 9.9999999624e-01 x T90 + 8.6745514449e-05 x z
# C:\Users\andre\AppData\Local\Temp\ipykernel_33008\1815344498.py:13: RuntimeWarning: invalid value encountered in log10
#   loglims = np.log10(lims)
# C:\Users\andre\AppData\Local\Temp\ipykernel_33008\1815344498.py:28: RuntimeWarning: invalid value encountered in log10
#   loglims = np.log10(lims)

# %% [markdown]
# Some relevant physical questions you might want to tackle include:
#
# - (1) Does the distribution contain different sub-populations? How many?
# - (2) What's the threshold between the classes?
# - (3) If you try two clustering methods, do you get more or less the same?
# - (4) How do methods respond to outliers?
# - (5) What variable(s) shows the multi-modality more evidently?
# - (6) Are all GRBs equally likely to be observed?
#
# Answers (by me - andrea pierini)
#
# - (1) yes, 2 populations
# - (2) clustering T90 yields T90 thresholds of about 5s with K-means, about 4s with GaussianMixture
# - (3) clustering with K-means or GaussianMixture yields similar results for the distribution of T90 (but slightly different T90 thresholds)
# - (4)
# - (5) T90 shows the multi-modality the most; after clustering with T90, redshift shows low signs of multimodality and fluence only extremely low signs of multimodality
# - (6)
